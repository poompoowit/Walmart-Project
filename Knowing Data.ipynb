# %%
import pandas as pd
import numpy as np
from datetime import datetime
pd.options.mode.chained_assignment = None  # default='warn'

# %%
train = pd.read_csv('./train.csv')
feature = pd.read_csv('./features.csv')
test = pd.read_csv('./test.csv')
train['Date'] = pd.to_datetime(train['Date'])
train['Week'] = train['Date'].dt.week
feature['Date'] = pd.to_datetime(feature['Date'])

# %%
feature
# Out:
#       Store       Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1 2010-02-05        42.31       2.572        NaN        NaN
# 1         1 2010-02-12        38.51       2.548        NaN        NaN
# 2         1 2010-02-19        39.93       2.514        NaN        NaN
# 3         1 2010-02-26        46.63       2.561        NaN        NaN
# 4         1 2010-03-05        46.50       2.625        NaN        NaN
# 5         1 2010-03-12        57.79       2.667        NaN        NaN
# 6         1 2010-03-19        54.58       2.720        NaN        NaN
# 7         1 2010-03-26        51.45       2.732        NaN        NaN
# 8         1 2010-04-02        62.27       2.719        NaN        NaN
# 9         1 2010-04-09        65.86       2.770        NaN        NaN
# 10        1 2010-04-16        66.32       2.808        NaN        NaN
# 11        1 2010-04-23        64.84       2.795        NaN        NaN
# ...

# %%
# store 1 Dept 1
check1 = train.loc[train['Store'] == 1 & train['Dept'].isin([1])]
pv = pd.pivot_table(check1, index=check1.Date.dt.week, columns=check1.Date.dt.year,
                    values='Weekly_Sales', aggfunc='sum')
pv.plot()

# %%
# store 1 Dept 2
check1 = train.loc[train['Store'] == 1 & train['Dept'].isin([2])]
pv = pd.pivot_table(check1, index=check1.Date.dt.week, columns=check1.Date.dt.year,
                    values='Weekly_Sales', aggfunc='sum')
pv.plot()

# %%
# store 1 Dept 3
check1 = train.loc[train['Store'] == 1 & train['Dept'].isin([3])]
pv = pd.pivot_table(check1, index=check1.Date.dt.week, columns=check1.Date.dt.year,
                    values='Weekly_Sales', aggfunc='sum')
pv.plot()

# %%
# store 3 Dept 1
check1 = train.loc[train['Dept'] == 1 & train['Store'].isin([3])]
check1
pv = pd.pivot_table(check1, index=check1.Date.dt.week, columns=check1.Date.dt.year,
                    values='Weekly_Sales', aggfunc='sum')
pv.plot()

# %%
result = pd.merge_asof(train, feature, on='Store',by='Date')
result = result.dropna()

# %%
result
# Out:
#         Store  Dept       Date  Weekly_Sales  IsHoliday_x  Week  Temperature  \
# 92          1     1 2011-11-11      18689.54        False    45        59.11
# 93          1     1 2011-11-18      19050.66        False    46        62.25
# 94          1     1 2011-11-25      20911.25         True    47        60.14
# 95          1     1 2011-12-02      25293.49        False    48        48.91
# 96          1     1 2011-12-09      33305.92        False    49        43.93
# 97          1     1 2011-12-16      45773.03        False    50        51.63
# 98          1     1 2011-12-23      46788.75        False    51        47.96
# 99          1     1 2011-12-30      23350.88         True    52        44.55
# 100         1     1 2012-01-06      16567.69        False     1        49.01
# 101         1     1 2012-01-13      16894.40        False     2        48.53
# 102         1     1 2012-01-20      18365.10        False     3        54.11
# ...

# %%
# store 1 Dept 1
check1 = result.loc[result['Store'] == 1 & result['Dept'].isin([1])]
check1.plot.scatter('Temperature', 'Weekly_Sales')

# %%
# store 1 Dept 1
check1 = result.loc[result['Store'] == 1 & result['Dept'].isin([1])]
check1.plot.scatter('Fuel_Price', 'Weekly_Sales')

# %%
# store 1 Dept 1
check1 = result.loc[result['Store'] == 1 & result['Dept'].isin([1])]
check1.plot.scatter('CPI', 'Weekly_Sales')

# %%
# store 1 Dept 1
check1 = result.loc[result['Store'] == 1 & result['Dept'].isin([1])]
check1.plot.scatter('Unemployment', 'Weekly_Sales')

# %%
# store 1 Dept 1
check1 = result.loc[result['Store'] == 1 & result['Dept'].isin([1])]
check1.plot.scatter('MarkDown1', 'Weekly_Sales')

# %%
# store 1 Dept 1
check1 = result.loc[result['Store'] == 1 & result['Dept'].isin([1])]
check1.plot.scatter('MarkDown2', 'Weekly_Sales')

# %%
# store 1 Dept 1
check1 = result.loc[result['Store'] == 1 & result['Dept'].isin([1])]
check1.plot.scatter('MarkDown3', 'Weekly_Sales')

# %%
# store 1 Dept 1
check1 = result.loc[result['Store'] == 1 & result['Dept'].isin([1])]
check1.plot.scatter('MarkDown4', 'Weekly_Sales')

# %%
# store 1 Dept 1
check1 = result.loc[result['Store'] == 1 & result['Dept'].isin([1])]
check1.plot.scatter('MarkDown5', 'Weekly_Sales')

# %%
# store 1 Dept 1
check1 = result.loc[result['Store'] == 1 & result['Dept'].isin([1])]
check1
check1.boxplot(column=['Weekly_Sales'], by=['IsHoliday_x'])
# Boxplot holiday (remove feature n/a)

# %%
# store 1 Dept 1
check1 = train.loc[train['Store'] == 1 & train['Dept'].isin([1])]
check1
check1.boxplot(column=['Weekly_Sales'], by=['IsHoliday'])
# Boxplot holiday (all)

# %%
# Many markdown can't see relations with Weekly_Sales
# Markdown2 and markdown3 are rough most value is at zero
# CPI , Temp and Fuel_price also can't see relations with Weekly_Sales
# Unemployment is very rough and only 5 value
# Time series is most significant value that can see the pattern

# %%
# From Data I select model for prediction to linear approach and tree approach
# For linear I select ridge regression because most feature are rough
# I select tree approach because same reason and use decision tree to test best feature group before test with another tree approach
